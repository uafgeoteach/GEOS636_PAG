# %%
def this_fails():
    return 1/0

try:
    this_fails()
except ZeroDivisionError as err:
    print("Handling runtime Error: ", err)

#we won't make it to the last print statement if we
#uncomment and execute the line below
#this_fails()

print("But this will execute")
# Out:
# Handling runtime Error:  division by zero
# But this will execute
